# %%
import pandas as pd

# %%
def ScorePhase0(GradedChallenge1=0, GradedChallenge2=0, GradedChallenge3=0, 
                     LiveCode1=0, LiveCode2=0, LiveCode3=0, Milestone1=0):

    CalcGC1 = GradedChallenge1 * (25 / 3 / 100)
    CalcGC2 = GradedChallenge2 * (25 / 3 / 100)
    CalcGC3 = GradedChallenge3 * (25 / 3 / 100)

    CalcLC1 = LiveCode1 * (35 / 3 / 100)
    CalcLC2 = LiveCode2 * (35 / 3 / 100)
    CalcLC3 = LiveCode3 * (35 / 3 / 100)

    CalcMl = Milestone1 * 0.4

    FinalScore = CalcGC1 + CalcGC2 + CalcGC3 + CalcLC1 + CalcLC2 + CalcLC3 + CalcMl

    Data = {
        'Assessment': ['Graded Challenge 1', 'Graded Challenge 2', 'Graded Challenge 3', 
                       'Live Code 1', 'Live Code 2', 'Live Code 3', 'Milestone 1'],
        'Total Score': [GradedChallenge1, GradedChallenge2, GradedChallenge3, 
                        LiveCode1, LiveCode2, LiveCode3, Milestone1],
        'Weight (%)': [25 / 3, 25 / 3, 25 / 3, 35 / 3, 35 / 3, 35 / 3, 40],
        'Score': [CalcGC1, CalcGC2, CalcGC3, CalcLC1, CalcLC2, CalcLC3, CalcMl]
    }
    
    df = pd.DataFrame(Data)
    
    df['Total Score'] = df['Total Score'].round(3)
    df['Weight (%)'] = df['Weight (%)'].round(3)
    df['Score'] = df['Score'].round(3)
    
    display(df.style.format({
        'Total Score': '{:.2f}',
        'Score': '{:.2f}',
        'Weight (%)': '{:.2f}'
    }).hide(axis="index"))
    
    print(f'Your Final Score Calculation is: {FinalScore:.2f}%')
    print()
    print('Note: This calculation is based solely on the scores provided.')
    print('Other factors may influence the final outcome.')

# %%
ScorePhase0(
    GradedChallenge1=100, 
    GradedChallenge2=96.39, 
    GradedChallenge3=87.5, 
    LiveCode1=85.48, 
    LiveCode2=95.24, 
    LiveCode3=100, 
    Milestone1=96.67
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffb5f">
#   <thead>
#     <tr>
#       <th id="T_ffb5f_level0_col0" class="col_heading level0 col0" >Assessment</th>
#       <th id="T_ffb5f_level0_col1" class="col_heading level0 col1" >Total Score</th>
#       <th id="T_ffb5f_level0_col2" class="col_heading level0 col2" >Weight (%)</th>
#       <th id="T_ffb5f_level0_col3" class="col_heading level0 col3" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ffb5f_row0_col0" class="data row0 col0" >Graded Challenge 1</td>
#       <td id="T_ffb5f_row0_col1" class="data row0 col1" >100.00</td>
#       <td id="T_ffb5f_row0_col2" class="data row0 col2" >8.33</td>
#       <td id="T_ffb5f_row0_col3" class="data row0 col3" >8.33</td>
#     </tr>
#     <tr>
#       <td id="T_ffb5f_row1_col0" class="data row1 col0" >Graded Challenge 2</td>
#       <td id="T_ffb5f_row1_col1" class="data row1 col1" >96.39</td>
# ...

# %%
def ScorePhase1(GradedChallenge4=0, GradedChallenge5=0, GradedChallenge6=0,
                LiveCode4=0, Presentation1=0, Milestones2=0):
    
    CalcGC4 = GradedChallenge4 * 0.1
    CalcGC5 = GradedChallenge5 * 0.1
    CalcGC6 = GradedChallenge6 * 0.1
    CalcLC = LiveCode4 * 0.2
    CalcPr = Presentation1 * 0.15
    CalcMl = Milestones2 * 0.35

    FinalScore = CalcGC4 + CalcGC5 + CalcGC6 + CalcLC + CalcPr + CalcMl

    Data = {
    'Assessment': ['Graded Challenge 4','Graded Challenge 5','Graded Challenge 6', 'Live Code', 'Presentation', 'Milestone 2'],
    'Total Score': [GradedChallenge4,GradedChallenge5,GradedChallenge6,LiveCode4,Presentation1,Milestones2],
    'Weight (%)':[10,10,10,20,15,35],
    'Score' : [CalcGC4, CalcGC5, CalcGC6, CalcLC, CalcPr, CalcMl]
    }
    
    df = pd.DataFrame(Data)

    styled_df = df.style.format({
        'Total Score': '{:.2f}',
        'Score': '{:.2f}'
    }).hide(axis="index")
    
    display(styled_df)
    print(f'Your Possible Final Score Calculation is: {FinalScore}%')
    print()
    print('Note: This calculation is based solely on the scores provided.')
    print('Other factors may influence the final outcome.')

# %%
ScorePhase1(
    GradedChallenge4= 0,
    GradedChallenge5= 0,
    GradedChallenge6= 0,
    LiveCode4= 0,
    Presentation1= 0,
    Milestones2= 0
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a3a4">
#   <thead>
#     <tr>
#       <th id="T_7a3a4_level0_col0" class="col_heading level0 col0" >Assessment</th>
#       <th id="T_7a3a4_level0_col1" class="col_heading level0 col1" >Total Score</th>
#       <th id="T_7a3a4_level0_col2" class="col_heading level0 col2" >Weight (%)</th>
#       <th id="T_7a3a4_level0_col3" class="col_heading level0 col3" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7a3a4_row0_col0" class="data row0 col0" >Graded Challenge 4</td>
#       <td id="T_7a3a4_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_7a3a4_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_7a3a4_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_7a3a4_row1_col0" class="data row1 col0" >Graded Challenge 5</td>
#       <td id="T_7a3a4_row1_col1" class="data row1 col1" >0.00</td>
# ...

# %%
# while True:
#     print("Let's count your score!")
    
#     def get_numeric_input(prompt):
#         while True:
#             try:
#                 value = float(input(prompt))
#                 return value
#             except ValueError:
#                 print("Invalid input. Please enter a numeric value.")

#     GradedChallenge4 = get_numeric_input("Enter your score for Graded Challenge 4 (out of 100): ")
#     GradedChallenge5 = get_numeric_input("Enter your score for Graded Challenge 5 (out of 100): ")
#     GradedChallenge6 = get_numeric_input("Enter your score for Graded Challenge 6 (out of 100): ")
#     LiveCode = get_numeric_input("Enter your score for Live Code (out of 100): ")
#     Presentation = get_numeric_input("Enter your score for Presentation (out of 100): ")
#     Milestones = get_numeric_input("Enter your score for Milestones (out of 100): ")

#     df = FinalScorePhase1(GradedChallenge4, GradedChallenge5, GradedChallenge6, LiveCode, Presentation, Milestones)
#     break
